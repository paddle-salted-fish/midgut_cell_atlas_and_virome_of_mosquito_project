# %%
import scanpy as sc
import pandas as pd

# %% [markdown]
# # get marker genes

# %%
adata = sc.read('./4.ann.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 40350 × 4000
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'mt_outlier', 'genes_outlier', 'batch', 'leiden_res', 'cluster', 'cluster_name'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden_res', 'leiden_res_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_pca_raw', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
list(adata.obs['cluster_name'].unique())
# Out:
# ['ISC/EB-prol',
#  'EC-like-2',
#  'EC',
#  'ISC/EB',
#  'Cardia-2',
#  'EE-3',
#  'Cardia-1',
#  'EE-1',
#  'EC-like-1',
#  'EE-2',
#  'EC-like-3',
#  '26',
#  'HC',
#  'VM',
#  'FBC',
#  '25']

# %%
sc.tl.rank_genes_groups(
    adata, 
    "cluster_name", 
    method="wilcoxon", 
    pts=True, 
    key_added='rank_genes_groups.wilcoxon'
)

# %%
sc.tl.filter_rank_genes_groups(
    adata,
    key="rank_genes_groups.wilcoxon",
    key_added="rank_genes_groups.wilcoxon.filter",
)

# %%
adata.uns['rank_genes_groups.wilcoxon']
# Out:
# {'params': {'groupby': 'cluster_name',
#   'reference': 'rest',
#   'method': 'wilcoxon',
#   'use_raw': True,
#   'layer': None,
#   'corr_method': 'benjamini-hochberg'},
#  'pts':                 ISC/EB  ISC/EB-prol  Cardia-1  Cardia-2        EC  EC-like-1  \
#  LOC110674347  0.002252     0.001762  0.003091  0.006073  0.017579   0.010849
#  LOC110674348  0.000000     0.000160  0.000000  0.000000  0.000088   0.000000
#  LOC5575839    0.051158     0.018421  0.018547  0.024107  0.061616   0.032113
#  LOC5575838    0.000322     0.000160  0.000000  0.000184  0.000439   0.000434
#  LOC5575837    0.201416     0.090982  0.120556  0.162311  0.439044   0.231882
#  ...                ...          ...       ...       ...       ...        ...
#  CFI06_mgt20   0.001931     0.000160  0.003091  0.002760  0.012393   0.008245
#  CFI06_mgr01   0.614865     0.388916  0.608964  0.649245  0.896106   0.839867
#  CFI06_mgt21   0.000000     0.000000  0.000000  0.000000  0.000000   0.000000
#  CFI06_mgt22   0.000000     0.000160  0.000000  0.000920  0.003692   0.002748
#  CFI06_mgt23   0.000000     0.000000  0.000000  0.000000  0.000000   0.000000
#
#                EC-like-2  EC-like-3      EE-1      EE-2      EE-3        VM  \
#  LOC110674347   0.005343   0.005405  0.010029  0.009524  0.005277  0.000000
#  LOC110674348   0.000000   0.000000  0.000000  0.000000  0.002639  0.000000
#  LOC5575839     0.017366   0.024324  0.040115  0.035714  0.031662  0.026490
#  LOC5575838     0.000267   0.000000  0.001433  0.000000  0.002639  0.003311
#  LOC5575837     0.095378   0.210811  0.213467  0.202381  0.245383  0.139073
#  ...                 ...        ...       ...       ...       ...       ...
#  CFI06_mgt20    0.000801   0.002703  0.001433  0.002381  0.002639  0.000000
#  CFI06_mgr01    0.361742   0.724324  0.765043  0.714286  0.836412  0.423841
#  CFI06_mgt21    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
#  CFI06_mgt22    0.000534   0.000000  0.001433  0.002381  0.000000  0.000000
#  CFI06_mgt23    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
#
#                     FBC        HC        25        26
#  LOC110674347  0.000000  0.000000  0.000000  0.011236
#  LOC110674348  0.000000  0.000000  0.005236  0.000000
#  LOC5575839    0.000000  0.035897  0.015707  0.033708
#  LOC5575838    0.000000  0.000000  0.000000  0.011236
#  LOC5575837    0.173913  0.146154  0.130890  0.179775
#  ...                ...       ...       ...       ...
#  CFI06_mgt20   0.000000  0.005128  0.015707  0.011236
#  CFI06_mgr01   0.630435  0.297436  0.549738  0.707865
#  CFI06_mgt21   0.000000  0.000000  0.000000  0.000000
#  CFI06_mgt22   0.000000  0.000000  0.000000  0.000000
#  CFI06_mgt23   0.000000  0.000000  0.000000  0.000000
#
#  [19269 rows x 16 columns],
#  'pts_rest':                 ISC/EB  ISC/EB-prol  Cardia-1  Cardia-2        EC  EC-like-1  \
#  LOC110674347  0.009586     0.010350  0.009118  0.009480  0.005660   0.008643
#  LOC110674348  0.000107     0.000088  0.000101  0.000115  0.000104   0.000120
#  LOC5575839    0.035927     0.040520  0.037403  0.039122  0.027474   0.038131
#  LOC5575838    0.000403     0.000440  0.000403  0.000430  0.000380   0.000389
#  LOC5575837    0.242629     0.266631  0.241392  0.251461  0.161081   0.241020
#  ...                ...          ...       ...       ...       ...        ...
#  CFI06_mgt20   0.006149     0.006861  0.005869  0.006301  0.003244   0.005323
#  CFI06_mgr01   0.686456     0.734395  0.682115  0.685875  0.596452   0.648084
#  CFI06_mgt21   0.000000     0.000000  0.000000  0.000000  0.000000   0.000000
#  CFI06_mgt22   0.001906     0.002052  0.001788  0.001890  0.001001   0.001555
#  CFI06_mgt23   0.000000     0.000000  0.000000  0.000000  0.000000   0.000000
#
#                EC-like-2  EC-like-3      EE-1      EE-2      EE-3        VM  \
#  LOC110674347   0.009397   0.009055  0.009003  0.009016  0.009057  0.009089
#  LOC110674348   0.000109   0.000100  0.000101  0.000100  0.000075  0.000100
#  LOC5575839     0.039118   0.037219  0.037047  0.037115  0.037152  0.037180
#  LOC5575838     0.000410   0.000400  0.000378  0.000401  0.000375  0.000375
#  LOC5575837     0.254186   0.239720  0.239912  0.239845  0.239399  0.240212
#  ...                 ...        ...       ...       ...       ...       ...
#  CFI06_mgt20    0.006338   0.005853  0.005901  0.005860  0.005854  0.005868
#  CFI06_mgr01    0.713579   0.680540  0.679461  0.680591  0.679468  0.682881
#  CFI06_mgt21    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
#  CFI06_mgt22    0.001885   0.001776  0.001765  0.001753  0.001776  0.001773
#  CFI06_mgt23    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
#
#                     FBC        HC        25        26
#  LOC110674347  0.009031  0.009109  0.009064  0.009016
#  LOC110674348  0.000099  0.000100  0.000075  0.000099
#  LOC5575839    0.037143  0.037112  0.037202  0.037108
#  LOC5575838    0.000397  0.000400  0.000398  0.000373
#  LOC5575837    0.239530  0.240365  0.239971  0.239587
#  ...                ...       ...       ...       ...
#  CFI06_mgt20   0.005831  0.005831  0.005777  0.005812
#  CFI06_mgr01   0.680999  0.684685  0.681566  0.680882
#  CFI06_mgt21   0.000000  0.000000  0.000000  0.000000
#  CFI06_mgt22   0.001762  0.001777  0.001768  0.001763
#  CFI06_mgt23   0.000000  0.000000  0.000000  0.000000
#
#  [19269 rows x 16 columns],
#  'names': rec.array([('LOC5563695', 'LOC5563695', 'LOC5568550', 'LOC5578882', 'LOC5569681', 'LOC5569681', 'LOC5571844', 'LOC5570613', 'LOC5569132', 'LOC5573899', 'LOC5568206', 'LOC5580173', 'LOC5571070', 'LOC110674010', 'LOC5579856', 'LOC5579498'),
#             ('LOC110676293', 'LOC110678734', 'LOC5579458', 'LOC5571712', 'LOC5577433', 'LOC5571844', 'LOC5566497', 'LOC5568702', 'LOC5578489', 'LOC110676394', 'LOC110676394', 'LOC5573031', 'LOC5573138', 'LOC5571086', 'LOC23687754', 'LOC5565599'),
#             ('LOC110678734', 'LOC23687936', 'LOC5568255', 'LOC5572257', 'LOC5578505', 'LOC5576966', 'LOC5572634', 'LOC5568583', 'LOC5573874', 'LOC5566917', 'LOC5573899', 'LOC5580231', 'LOC5573132', 'LOC5570587', 'LOC5576459', 'LOC110676679'),
#             ...,
#             ('LOC5569681', 'LOC5574655', 'LOC5570244', 'LOC5578625', 'LOC5568355', 'LOC110675610', 'CFI06_mgp11', 'LOC5564567', 'LOC110677919', 'LOC5564713', 'LOC23687618', 'LOC5574526', 'LOC5567341', 'CFI06_mgp08', 'LOC110675609', 'LOC5575037'),
#             ('LOC23687442', 'LOC23687442', 'LOC5566228', 'LOC5577034', 'LOC5563695', 'LOC5578831', 'CFI06_mgp12', 'LOC5565700', 'LOC23687618', 'LOC110677919', 'LOC5576653', 'LOC110675611', 'LOC5566220', 'LOC5574458', 'LOC5574458', 'LOC110677919'),
#             ('LOC5567341', 'LOC5567341', 'LOC5578625', 'LOC110676045', 'LOC5566497', 'LOC5574526', 'CFI06_mgp08', 'LOC5572372', 'LOC5578368', 'LOC23687618', 'LOC5564713', 'LOC110675609', 'LOC5574458', 'LOC5567341', 'LOC5567341', 'LOC5578368')],
#            dtype=[('ISC/EB', 'O'), ('ISC/EB-prol', 'O'), ('Cardia-1', 'O'), ('Cardia-2', 'O'), ('EC', 'O'), ('EC-like-1', 'O'), ('EC-like-2', 'O'), ('EC-like-3', 'O'), ('EE-1', 'O'), ('EE-2', 'O'), ('EE-3', 'O'), ('VM', 'O'), ('FBC', 'O'), ('HC', 'O'), ('25', 'O'), ('26', 'O')]),
#  'scores': rec.array([( 70.82203 ,  101.00862 ,  43.37034 , 110.36321,  90.16182 ,  81.566795,  38.875797,  25.072868,  43.544544,  34.651634,  33.252216,  24.259724,  9.433691 ,  32.36471 ,  15.215178, 15.871582 ),
#             ( 66.05391 ,   89.06455 ,  42.497356, 110.00733,  89.23808 ,  77.659164,  33.11459 ,  22.935514,  43.385937,  31.055761,  32.82752 ,  23.74814 ,  9.432298 ,  29.94762 ,  14.86305 , 15.764277 ),
#             ( 61.60067 ,   76.773636,  41.233685, 107.5955 ,  88.0028  ,  76.63199 ,  31.960148,  21.8691  ,  42.960575,  30.161987,  32.477684,  23.567343,  9.406271 ,  29.789389,  13.750349, 15.210808 ),
#             ...,
#             (-65.217995,  -96.30858 , -21.090382, -79.2705 , -38.431026, -48.02546 , -47.137516, -12.262253, -26.402834, -14.857244, -25.507412, -10.097504, -5.4359474, -15.445877, -10.363903, -8.3437805),
#             (-65.609   ,  -96.627525, -21.538284, -79.80063, -39.95397 , -48.84833 , -48.055447, -12.437808, -27.184774, -14.86782 , -25.643236, -10.562272, -5.703423 , -15.564915, -10.554418, -8.622857 ),
#             (-69.7089  , -104.99031 , -22.644472, -81.01607, -80.126595, -70.91794 , -48.942513, -15.538912, -28.16296 , -14.878656, -25.96253 , -11.735232, -5.9723673, -16.56355 , -11.012532, -9.890937 )],
#            dtype=[('ISC/EB', '<f4'), ('ISC/EB-prol', '<f4'), ('Cardia-1', '<f4'), ('Cardia-2', '<f4'), ('EC', '<f4'), ('EC-like-1', '<f4'), ('EC-like-2', '<f4'), ('EC-like-3', '<f4'), ('EE-1', '<f4'), ('EE-2', '<f4'), ('EE-3', '<f4'), ('VM', '<f4'), ('FBC', '<f4'), ('HC', '<f4'), ('25', '<f4'), ('26', '<f4')]),
#  'pvals': rec.array([(0., 0., 0.00000000e+000, 0., 0., 0., 0.00000000e+000, 9.83345330e-139, 0.00000000e+000, 4.22079112e-263, 1.89624006e-242, 5.22079784e-130, 3.95907491e-21, 8.61458220e-230, 2.80458574e-52, 9.96963375e-57),
#             (0., 0., 0.00000000e+000, 0., 0., 0., 1.83265985e-240, 2.05560011e-116, 0.00000000e+000, 9.53777769e-212, 2.38466169e-236, 1.14843511e-124, 4.01202727e-21, 4.72532230e-197, 5.72577511e-50, 5.47951981e-56),
#             (0., 0., 0.00000000e+000, 0., 0., 0., 3.90505391e-224, 5.11557959e-106, 0.00000000e+000, 7.46923325e-200, 2.20314981e-231, 8.33687776e-123, 5.14052630e-21, 5.36108791e-195, 5.06846673e-43, 2.99820039e-52),
#             ...,
#             (0., 0., 9.74741114e-099, 0., 0., 0., 0.00000000e+000, 1.44427249e-034, 1.27128191e-153, 6.24419497e-050, 1.63127986e-143, 5.66663903e-024, 5.45060034e-08, 8.04263569e-054, 3.61885347e-25, 7.19525119e-17),
#             (0., 0., 6.81863487e-103, 0., 0., 0., 0.00000000e+000, 1.62914225e-035, 9.83134527e-163, 5.33218168e-050, 5.03025993e-145, 4.45740871e-026, 1.17425171e-08, 1.26038070e-054, 4.84636137e-26, 6.53041755e-18),
#             (0., 0., 1.58158717e-113, 0., 0., 0., 0.00000000e+000, 1.89169540e-054, 1.66295133e-174, 4.53513758e-050, 1.31285387e-148, 8.40950919e-032, 2.33835131e-09, 1.27824110e-061, 3.32525786e-28, 4.55742840e-23)],
#            dtype=[('ISC/EB', '<f8'), ('ISC/EB-prol', '<f8'), ('Cardia-1', '<f8'), ('Cardia-2', '<f8'), ('EC', '<f8'), ('EC-like-1', '<f8'), ('EC-like-2', '<f8'), ('EC-like-3', '<f8'), ('EE-1', '<f8'), ('EE-2', '<f8'), ('EE-3', '<f8'), ('VM', '<f8'), ('FBC', '<f8'), ('HC', '<f8'), ('25', '<f8'), ('26', '<f8')]),
#  'pvals_adj': rec.array([(0., 0., 0.00000000e+000, 0., 0., 0., 0.00000000e+000, 1.89480812e-134, 0.00000000e+000, 8.13304241e-259, 3.65386497e-238, 1.00599554e-125, 3.30176004e-17, 1.65994384e-225, 5.40415626e-48, 1.92104873e-52),
#             (0., 0., 0.00000000e+000, 0., 0., 0., 2.35423484e-237, 1.98046793e-112, 0.00000000e+000, 9.18917191e-208, 2.29750230e-232, 1.10645980e-120, 3.30176004e-17, 4.55261177e-193, 5.51649803e-46, 5.27924337e-52),
#             (0., 0., 0.00000000e+000, 0., 0., 0., 3.76232418e-221, 3.28573677e-102, 0.00000000e+000, 4.79748852e-196, 1.41508312e-227, 5.35477658e-119, 3.30176004e-17, 3.44342676e-191, 3.25547618e-39, 1.92574411e-48),
#             ...,
#             (0., 0., 5.86946454e-096, 0., 0., 0., 0.00000000e+000, 6.78772845e-032, 1.06505788e-150, 4.45627381e-047, 1.96457072e-140, 4.54960281e-021, 6.17809517e-05, 5.96052104e-051, 8.71646094e-22, 6.02805631e-14),
#             (0., 0., 4.37960918e-100, 0., 0., 0., 0.00000000e+000, 7.84798552e-033, 8.61091782e-160, 3.95176187e-047, 6.46187191e-142, 3.90408220e-023, 1.41416601e-05, 9.71451029e-052, 1.55640895e-22, 6.29173079e-15),
#             (0., 0., 1.05088287e-110, 0., 0., 0., 0.00000000e+000, 1.73576565e-051, 1.78018940e-171, 3.64114858e-047, 1.80695580e-145, 8.10214163e-029, 3.75480762e-06, 1.07088816e-058, 1.28148787e-24, 5.85447253e-20)],
#            dtype=[('ISC/EB', '<f8'), ('ISC/EB-prol', '<f8'), ('Cardia-1', '<f8'), ('Cardia-2', '<f8'), ('EC', '<f8'), ('EC-like-1', '<f8'), ('EC-like-2', '<f8'), ('EC-like-3', '<f8'), ('EE-1', '<f8'), ('EE-2', '<f8'), ('EE-3', '<f8'), ('VM', '<f8'), ('FBC', '<f8'), ('HC', '<f8'), ('25', '<f8'), ('26', '<f8')]),
#  'logfoldchanges': rec.array([( 8.027092 ,  8.494359 , 14.40218   ,  4.3166513,  1.4115441,  1.4079967,  1.051217 , 11.312121 , 16.115728  , 14.860746  , 15.334094 , 13.764691 , 15.490716 , 17.01103  , 13.061403 , 12.556725 ),
#             ( 7.5459065,  1.1903107, 13.32965   ,  6.0293837,  5.412324 ,  1.3606327,  1.5544596,  5.865161 , 14.296705  , 11.887003  , 13.915462 , 13.413625 , 15.900493 ,  9.758952 , 13.875686 , 17.82604  ),
#             ( 1.0879197,  0.84093  ,  9.166332  ,  9.027951 ,  3.2564301,  1.4186418,  1.1274838,  4.7081184, 14.104712  , 11.212935  , 13.547157 , 13.659195 , 13.410751 , 10.433621 , 10.525268 , 13.328919 ),
#             ...,
#             (-1.9791969, -5.167544 , -0.61951256, -1.0309951, -2.6622589, -1.2313399, -2.5717034, -1.3857285, -1.13041   , -0.54775804, -1.1404403, -1.7173983, -1.8397616, -0.8640108, -3.8152814, -0.684692 ),
#             (-3.0950427, -4.2259407, -0.6867569 , -1.0261816, -3.2580462, -1.1631442, -2.2620516, -2.5994582, -0.72708267, -0.6591468 , -1.5459375, -3.6697586, -3.9288301, -2.5190315, -2.6437707, -0.7748216),
#             (-2.1008778, -3.1527197, -0.9656558 , -0.8254951, -2.0839145, -0.9267306, -2.1546528, -2.5608177, -1.043865  , -0.42631394, -1.3233416, -3.5331254, -3.4009752, -1.4811828, -1.5845213, -0.7008019)],
#            dtype=[('ISC/EB', '<f4'), ('ISC/EB-prol', '<f4'), ('Cardia-1', '<f4'), ('Cardia-2', '<f4'), ('EC', '<f4'), ('EC-like-1', '<f4'), ('EC-like-2', '<f4'), ('EC-like-3', '<f4'), ('EE-1', '<f4'), ('EE-2', '<f4'), ('EE-3', '<f4'), ('VM', '<f4'), ('FBC', '<f4'), ('HC', '<f4'), ('25', '<f4'), ('26', '<f4')])}

# %%
name = pd.DataFrame(adata.uns['rank_genes_groups.wilcoxon.filter']['names'])
padj = pd.DataFrame(adata.uns['rank_genes_groups.wilcoxon.filter']['pvals_adj'])
lgFC = pd.DataFrame(adata.uns['rank_genes_groups.wilcoxon.filter']['logfoldchanges'])
scores = pd.DataFrame(adata.uns['rank_genes_groups.wilcoxon']['scores'])
pts = adata.uns['rank_genes_groups.wilcoxon.filter']['pts']
pts_rest = adata.uns['rank_genes_groups.wilcoxon.filter']['pts_rest']

dfs = []
for cluster in name.columns:
    df = pd.concat(
        [
            name[cluster].dropna(), 
            padj[cluster].dropna(), 
            lgFC[cluster].dropna(),
            scores[cluster].dropna(),
        ], 
        axis=1
    )
    df.columns = ['names', 'pvals_adj', 'logfoldchanges', 'scores']
    df.set_index(['names'], inplace=True)

    pts_df = pd.concat([pts[[cluster]], pts_rest[[cluster]]], axis=1)
    pts_df.columns = ['pts', 'pts_rest']

    df = df.merge(pts_df, left_index=True, right_index=True, how='inner')
    df['leiden_res'] = cluster

    dfs.append(df)

markg = pd.concat(dfs, axis=0)
markg = markg.sort_values(['leiden_res', 'scores'], ascending=False)

markg
# Out:
#                 pvals_adj  logfoldchanges     scores       pts  pts_rest  \
# names
# LOC5580173  1.005996e-125       13.764691  24.259724  0.811258  0.006817
# LOC5573031  1.106460e-120       13.413625  23.748140  0.794702  0.008465
# LOC5580231  5.354777e-119       13.659195  23.567343  0.788079  0.006417
# LOC5576127   6.167170e-97       13.081758  21.294367  0.711921  0.003970
# LOC5568444   2.881767e-94       12.833956  20.993767  0.701987  0.004619
# ...                   ...             ...        ...       ...       ...
# LOC5573103   1.263470e-02        2.202772   3.612218  0.256545  0.133445
# LOC5568355   5.356542e-02        1.280174   3.126205  0.450262  0.358575
# LOC5567637   8.355446e-02        1.249147   2.962382  0.335079  0.273139
# LOC5566119   9.247537e-02        1.141814   2.922727  0.345550  0.289026
# LOC5567068   1.341111e-01        1.270964   2.777524  0.303665  0.237581
#
#            leiden_res
# names
# LOC5580173         VM
# LOC5573031         VM
# LOC5580231         VM
# LOC5576127         VM
# LOC5568444         VM
# ...               ...
# LOC5573103         25
# LOC5568355         25
# LOC5567637         25
# LOC5566119         25
# LOC5567068         25
#
# [3146 rows x 6 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 40350 × 4000
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'mt_outlier', 'genes_outlier', 'batch', 'leiden_res', 'cluster', 'cluster_name'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden_res', 'leiden_res_colors', 'log1p', 'neighbors', 'pca', 'umap', 'rank_genes_groups.wilcoxon', 'rank_genes_groups.wilcoxon.filter'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_pca_raw', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
markg.to_csv('./5.marker_genes.csv')
